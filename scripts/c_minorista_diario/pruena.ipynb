# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

a=pd.read_csv("..\\..\\data\\processed\\df_indicadores_sm.csv", encoding="utf-8",sep=";")

plt.figure(figsize=(8, 6))
sns.lineplot(x='fecha_stata', y='PRECIOVENTA_may', hue='COD_PROD', data=a[a.COD_PROD==37], marker='o', markersize=8, palette='husl')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 5
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 5 a=pd.read_csv("..\\..\\data\\processed\\df_indicadores_sm.csv", encoding="utf-8",sep=";")
#       7 plt.figure(figsize=(8, 6))
#       8 sns.lineplot(x='fecha_stata', y='PRECIOVENTA_may', hue='COD_PROD', data=a[a.COD_PROD==37], marker='o', markersize=8, palette='husl')
#
# ...

# %%
a.COD_PROD.unique()
# Out:
# array([46, 45, 37, 36, 47, 48, 28, 19], dtype=int64)
